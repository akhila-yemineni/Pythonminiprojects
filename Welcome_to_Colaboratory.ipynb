# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagalakshmi-satha/python-mini-project/blob/main/Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))

idata ={'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [89,
#   79,
#   53,
#   55,
#   5,
#   43,
#   81,
#   82,
#   75,
#   44,
#   34,
#   6,
#   93,
#   85,
#   93,
#   9,
#   45,
#   21,
#   45,
#   69,
#   75,
#   69,
#   95,
#   38,
#   6,
#   52,
#   62,
#   32,
#   26,
#   32,
#   20,
#   97,
#   34,
#   96,
#   97,
#   32,
#   90,
#   2,
#   77,
#   36,
#   42,
#   51,
#   31,
#   60,
#   36,
#   35,
#   55,
#   60,
#   52,
#   29,
#   19,
#   22,
#   91,
#   4,
#   98,
#   23,
#   48,
#   75,
#   35,
#   22,
#   17,
#   100,
#   5,
#   78,
#   26,
#   71,
#   18,
#   90,
#   43,
#   7,
#   91,
#   70,
#   55,
#   14,
#   66,
#   78,
#   2,
#   76,
#   23,
#   73,
#   22,
#   71,
#   58,
#   57,
#   0,
#   92,
#   51,
#   73,
#   25,
#   34,
#   13,
#   8,
#   17,
#   29,
#   8,
#   40,
#   67,
#   55,
#   56,
#   4],
#  'Height': [100,
#   9,
#   29,
#   60,
#   92,
#   92,
#   43,
#   13,
#   83,
#   30,
#   69,
#   70,
#   26,
#   51,
#   82,
#   76,
#   1,
#   68,
#   80,
#   78,
#   32,
#   36,
#   49,
#   19,
#   6,
#   89,
#   12,
#   91,
#   95,
#   59,
#   11,
#   30,
#   82,
#   100,
#   26,
#   92,
#   20,
#   53,
#   91,
#   74,
#   3,
#   79,
#   29,
#   12,
#   48,
#   42,
#   72,
#   51,
#   6,
#   57,
#   31,
#   79,
#   86,
#   60,
#   78,
#   17,
#   63,
#   87,
#   46,
#   36,
#   76,
#   62,
#   24,
#   64,
#   82,
#   10,
#   57,
#   18,
#   71,
#   83,
#   92,
#   16,
#   17,
#   25,
#   69,
#   74,
#   9,
#   66,
#   66,
#   79,
#   52,
#   30,
#   70,
#   69,
#   2,
#   39,
#   28,
#   57,
#   52,
#   87,
#   30,
#   15,
#   73,
#   43,
#   84,
#   74,
#   67,
#   40,
#   34,
#   48],
#  'Weight': [69,
#   22,
#   61,
#   39,
#   60,
#   0,
#   88,
#   99,
#   85,
#   54,
#   12,
#   11,
#   33,
#   80,
#   62,
#   16,
#   68,
#   60,
#   56,
#   17,
#   68,
#   86,
#   9,
#   8,
#   85,
#   22,
#   6,
#   94,
#   47,
#   69,
#   62,
#   30,
#   20,
#   56,
#   58,
#   53,
#   86,
#   50,
#   89,
#   2,
#   68,
#   68,
#   72,
#   78,
#   1,
#   11,
#   92,
#   93,
#   95,
#   48,
#   95,
#   29,
#   49,
#   29,
#   38,
#   74,
#   25,
#   70,
#   91,
#   50,
#   66,
#   87,
#   56,
#   88,
#   100,
#   58,
#   82,
#   39,
#   20,
#   11,
#   88,
#   13,
#   37,
#   54,
#   88,
#   83,
#   6,
#   81,
#   83,
#   94,
#   40,
#   16,
#   100,
#   21,
#   98,
#   21,
#   53,
#   64,
#   97,
#   64,
#   65,
#   97,
#   9,
#   98,
#   93,
#   22,
#   11,
#   28,
#   0,
#   22],
#  'Speed': [61,
#   24,
#   5,
#   72,
#   14,
#   100,
#   59,
#   64,
#   63,
#   2,
#   82,
#   63,
#   57,
#   64,
#   41,
#   68,
#   83,
#   0,
#   40,
#   55,
#   85,
#   26,
#   61,
#   98,
#   80,
#   35,
#   48,
#   12,
#   96,
#   61,
#   95,
#   72,
#   78,
#   64,
#   58,
#   48,
#   65,
#   40,
#   24,
#   18,
#   71,
#   45,
#   2,
#   46,
#   9,
#   96,
#   0,
#   98,
#   53,
#   42,
#   95,
#   45,
#   89,
#   65,
#   0,
#   65,
#   14,
#   41,
#   30,
#   48,
#   47,
#   35,
#   52,
#   28,
#   34,
#   77,
#   0,
#   18,
#   25,
#   100,
#   52,
#   26,
#   53,
#   47,
#   84,
#   89,
#   69,
#   68,
#   55,
#   42,
#   65,
#   78,
#   41,
#   15,
#   88,
#   42,
#   42,
#   93,
#   78,
#   94,
#   93,
#   73,
#   25,
#   1,
#   41,
#   39,
#   56,
#   20,
#   55,
#   12]}

# %%
import pandas as pd
df1=pd.DataFrame(idata)

# %%
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    48.450000   52.550000   54.210000   51.870000
# std     29.229629   28.136168   31.056903   28.125137
# min      0.000000    1.000000    0.000000    0.000000
# 25%     23.000000   29.000000   22.000000   33.000000
# 50%     46.500000   57.000000   58.000000   53.000000
# 75%     73.500000   76.500000   83.500000   72.000000
# max    100.000000  100.000000  100.000000  100.000000

# %%
df1.sort_index(ascending=True)
# Out:
#     Age  Height  Weight  Speed
# 0    89     100      69     61
# 1    79       9      22     24
# 2    53      29      61      5
# 3    55      60      39     72
# 4     5      92      60     14
# ..  ...     ...     ...    ...
# 95   40      74      22     39
# 96   67      67      11     56
# 97   55      40      28     20
# 98   56      34       0     55
# 99    4      48      22     12
#
# [100 rows x 4 columns]

# %%
df1['Weight']>50
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4      True
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Weight, Length: 100, dtype: bool

# %%
df1['Age']>50
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
#       ...
# 95    False
# 96     True
# 97     True
# 98     True
# 99    False
# Name: Age, Length: 100, dtype: bool

# %%
filter1=df1['Weight']>50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 0    89     100      69     61
# 2    53      29      61      5
# 4     5      92      60     14
# 6    81      43      88     59
# 7    82      13      99     64
# 8    75      83      85     63
# 9    44      30      54      2
# 13   85      51      80     64
# 14   93      82      62     41
# 16   45       1      68     83
# 17   21      68      60      0
# 18   45      80      56     40
# 20   75      32      68     85
# 21   69      36      86     26
# 24    6       6      85     80
# 27   32      91      94     12
# 29   32      59      69     61
# 30   20      11      62     95
# 33   96     100      56     64
# 34   97      26      58     58
# 35   32      92      53     48
# 36   90      20      86     65
# 38   77      91      89     24
# 40   42       3      68     71
# 41   51      79      68     45
# 42   31      29      72      2
# 43   60      12      78     46
# 46   55      72      92      0
# 47   60      51      93     98
# 48   52       6      95     53
# 50   19      31      95     95
# 55   23      17      74     65
# 57   75      87      70     41
# 58   35      46      91     30
# 60   17      76      66     47
# 61  100      62      87     35
# 62    5      24      56     52
# 63   78      64      88     28
# 64   26      82     100     34
# 65   71      10      58     77
# 66   18      57      82      0
# 70   91      92      88     52
# 73   14      25      54     47
# 74   66      69      88     84
# 75   78      74      83     89
# 77   76      66      81     68
# 78   23      66      83     55
# 79   73      79      94     42
# 82   58      70     100     41
# 84    0       2      98     88
# 86   51      28      53     42
# 87   73      57      64     93
# 88   25      52      97     78
# 89   34      87      64     94
# 90   13      30      65     93
# 91    8      15      97     73
# 93   29      43      98      1
# 94    8      84      93     41

# %%
filter2=df1['Age']>50

# %%
df1[filter1|filter2]
# Out:
#     Age  Height  Weight  Speed
# 0    89     100      69     61
# 1    79       9      22     24
# 2    53      29      61      5
# 3    55      60      39     72
# 4     5      92      60     14
# ..  ...     ...     ...    ...
# 93   29      43      98      1
# 94    8      84      93     41
# 96   67      67      11     56
# 97   55      40      28     20
# 98   56      34       0     55
#
# [77 rows x 4 columns]

# %%
df1.loc[filter1|filter2]
# Out:
#     Age  Height  Weight  Speed
# 0    89     100      69     61
# 1    79       9      22     24
# 2    53      29      61      5
# 3    55      60      39     72
# 4     5      92      60     14
# ..  ...     ...     ...    ...
# 93   29      43      98      1
# 94    8      84      93     41
# 96   67      67      11     56
# 97   55      40      28     20
# 98   56      34       0     55
#
# [77 rows x 4 columns]
